# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
def get_current_weather(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/weather"
    payload = {
        "appid": api_key,
        "q": city
    }
    r = requests.get(url, params = payload)
    
    if r.status_code == 200:
        print(f"Processing Record {len(all_cities)}| {city}")
        return r.json()
    else:
        print("City not found. Skipping...")
        return None

# %%
all_cities = []
print('''
Beginning Data Retrieval
--------------------------------''')
for city in cities:
    result = get_current_weather(city, api_key)
    if result:
        all_cities.append(result)
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 0| hinton
# Processing Record 1| ilebo
# City not found. Skipping...
# Processing Record 2| punta arenas
# Processing Record 3| pevek
# Processing Record 4| adelaide
# Processing Record 5| pereslavl-zalesskiy
# Processing Record 6| thompson
# Processing Record 7| puerto baquerizo moreno
# Processing Record 8| broome
# Processing Record 9| hilo
# Processing Record 10| mataura
# Processing Record 11| souillac
# Processing Record 12| tecoanapa
# Processing Record 13| avera
# Processing Record 14| hobart
# Processing Record 15| saint george
# Processing Record 16| umm lajj
# Processing Record 17| jamestown
# Processing Record 18| albany
# Processing Record 19| port alfred
# Processing Record 20| rikitea
# City not found. Skipping...
# Processing Record 21| danjiangkou
# Processing Record 22| nanakuli
# City not found. Skipping...
# Processing Record 23| bethel
# Processing Record 24| vaini
# Processing Record 25| ushuaia
# Processing Record 26| tame
# Processing Record 27| bluff
# Processing Record 28| peabiru
# Processing Record 29| krasnohrad
# Processing Record 30| ternate
# Processing Record 31| yellowknife
# Processing Record 32| east london
# Processing Record 33| esperance
# Processing Record 34| butaritari
# Processing Record 35| sioux lookout
# Processing Record 36| namibe
# Processing Record 37| suluq
# Processing Record 38| rudnyy
# Processing Record 39| rabo de peixe
# Processing Record 40| caravelas
# Processing Record 41| agadir
# City not found. Skipping...
# Processing Record 42| constitucion
# Processing Record 43| arinos
# Processing Record 44| ponta do sol
# Processing Record 45| pontianak
# Processing Record 46| georgetown
# City not found. Skipping...
# Processing Record 47| busselton
# Processing Record 48| mangaratiba
# Processing Record 49| lavrentiya
# Processing Record 50| sao felix do xingu
# Processing Record 51| el retorno
# City not found. Skipping...
# Processing Record 52| ancud
# Processing Record 53| madimba
# Processing Record 54| kavaratti
# Processing Record 55| mega
# Processing Record 56| sitka
# Processing Record 57| nobeoka
# Processing Record 58| monforte de lemos
# Processing Record 59| qaanaaq
# Processing Record 60| luau
# Processing Record 61| codrington
# Processing Record 62| kuytun
# Processing Record 63| klaksvik
# City not found. Skipping...
# Processing Record 64| pisco
# Processing Record 65| tuktoyaktuk
# Processing Record 66| casablanca
# Processing Record 67| cholet
# Processing Record 68| muddebihal
# Processing Record 69| cape town
# Processing Record 70| airai
# Processing Record 71| conde
# City not found. Skipping...
# Processing Record 72| talnakh
# Processing Record 73| mar del plata
# Processing Record 74| atuona
# Processing Record 75| taoudenni
# Processing Record 76| biankouma
# Processing Record 77| gat
# Processing Record 78| erzin
# Processing Record 79| dubna
# Processing Record 80| todos santos
# Processing Record 81| great falls
# Processing Record 82| kiama
# Processing Record 83| kodiak
# Processing Record 84| palaikastron
# Processing Record 85| pitkyaranta
# Processing Record 86| mahebourg
# City not found. Skipping...
# Processing Record 87| kununurra
# Processing Record 88| margate
# Processing Record 89| lac du bonnet
# Processing Record 90| chuy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 91| ferme-neuve
# Processing Record 92| le port
# Processing Record 93| bredasdorp
# Processing Record 94| torbay
# Processing Record 95| valdivia
# Processing Record 96| nikolskoye
# Processing Record 97| carnarvon
# Processing Record 98| lasa
# City not found. Skipping...
# Processing Record 99| upernavik
# Processing Record 100| baykit
# Processing Record 101| esfarayen
# Processing Record 102| la belgica
# Processing Record 103| talaya
# Processing Record 104| hambantota
# Processing Record 105| tessalit
# Processing Record 106| wilmington
# Processing Record 107| kapaa
# Processing Record 108| milkovo
# Processing Record 109| port hawkesbury
# Processing Record 110| severo-kurilsk
# Processing Record 111| kieta
# City not found. Skipping...
# Processing Record 112| rovaniemi
# Processing Record 113| pundaguitan
# Processing Record 114| batman
# Processing Record 115| norman wells
# Processing Record 116| komsomolskiy
# Processing Record 117| sao luis do quitunde
# Processing Record 118| port blair
# Processing Record 119| barrow
# Processing Record 120| deputatskiy
# Processing Record 121| kaitangata
# Processing Record 122| cherskiy
# Processing Record 123| nanortalik
# Processing Record 124| kaeo
# Processing Record 125| antalaha
# Processing Record 126| lagoa
# Processing Record 127| saint-philippe
# Processing Record 128| rawson
# Processing Record 129| kasongo-lunda
# Processing Record 130| podgorenskiy
# Processing Record 131| tumarbong
# Processing Record 132| manakara
# Processing Record 133| khatanga
# City not found. Skipping...
# Processing Record 134| christchurch
# Processing Record 135| mabaruma
# Processing Record 136| bilma
# Processing Record 137| katsuura
# Processing Record 138| nantucket
# Processing Record 139| castro
# Processing Record 140| mogadishu
# City not found. Skipping...
# Processing Record 141| vao
# Processing Record 142| pangnirtung
# Processing Record 143| port augusta
# Processing Record 144| pokhvistnevo
# Processing Record 145| padang
# Processing Record 146| beihai
# Processing Record 147| boden
# Processing Record 148| victoria
# Processing Record 149| faanui
# Processing Record 150| manbij
# Processing Record 151| new norfolk
# Processing Record 152| esfahan
# Processing Record 153| tasiilaq
# Processing Record 154| manzhouli
# Processing Record 155| cabo san lucas
# Processing Record 156| ondangwa
# Processing Record 157| kenai
# City not found. Skipping...
# Processing Record 158| high level
# Processing Record 159| sorong
# Processing Record 160| dandong
# City not found. Skipping...
# Processing Record 161| longyearbyen
# Processing Record 162| ilulissat
# Processing Record 163| khandyga
# Processing Record 164| dudinka
# City not found. Skipping...
# Processing Record 165| tacuarembo
# Processing Record 166| den helder
# Processing Record 167| turochak
# Processing Record 168| hermanus
# Processing Record 169| poum
# Processing Record 170| avarua
# Processing Record 171| provideniya
# City not found. Skipping...
# Processing Record 172| southbridge
# City not found. Skipping...
# Processing Record 173| arraial do cabo
# Processing Record 174| puerto ayora
# City not found. Skipping...
# Processing Record 175| coquimbo
# Processing Record 176| ngunguru
# Processing Record 177| makakilo city
# Processing Record 178| vanimo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 179| mangan
# Processing Record 180| balakhta
# Processing Record 181| urengoy
# Processing Record 182| kavieng
# Processing Record 183| oistins
# Processing Record 184| palmas
# City not found. Skipping...
# Processing Record 185| yar-sale
# Processing Record 186| sheregesh
# Processing Record 187| koumac
# Processing Record 188| sinnamary
# Processing Record 189| chegdomyn
# Processing Record 190| saint-pierre
# Processing Record 191| van
# Processing Record 192| angoram
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 193| fukue
# Processing Record 194| dingle
# Processing Record 195| mantua
# Processing Record 196| bonavista
# Processing Record 197| meulaboh
# City not found. Skipping...
# Processing Record 198| komsomolets
# Processing Record 199| sola
# Processing Record 200| shahr-e babak
# Processing Record 201| dubbo
# Processing Record 202| melo
# Processing Record 203| tutoia
# Processing Record 204| malaya serdoba
# Processing Record 205| necochea
# Processing Record 206| sao filipe
# Processing Record 207| placer
# Processing Record 208| tiksi
# Processing Record 209| damietta
# Processing Record 210| chinhoyi
# Processing Record 211| ribeira grande
# Processing Record 212| hami
# Processing Record 213| dikson
# Processing Record 214| hay river
# Processing Record 215| leningradskiy
# Processing Record 216| kungurtug
# Processing Record 217| mount isa
# Processing Record 218| vila franca do campo
# Processing Record 219| marawi
# Processing Record 220| hithadhoo
# Processing Record 221| porto nacional
# Processing Record 222| kahului
# Processing Record 223| hohhot
# Processing Record 224| gizo
# Processing Record 225| maniitsoq
# Processing Record 226| salalah
# Processing Record 227| the valley
# Processing Record 228| ixtapa
# City not found. Skipping...
# Processing Record 229| merauke
# Processing Record 230| mackenzie
# Processing Record 231| aleksandro-nevskiy
# Processing Record 232| cayenne
# Processing Record 233| ust-tsilma
# Processing Record 234| valparaiso
# City not found. Skipping...
# Processing Record 235| brae
# Processing Record 236| aksarka
# Processing Record 237| eureka
# Processing Record 238| sur
# Processing Record 239| saint-georges
# Processing Record 240| male
# Processing Record 241| nicoya
# City not found. Skipping...
# Processing Record 242| kijang
# Processing Record 243| chokurdakh
# Processing Record 244| havoysund
# Processing Record 245| luderitz
# Processing Record 246| vostok
# Processing Record 247| la ronge
# Processing Record 248| havre-saint-pierre
# Processing Record 249| algiers
# Processing Record 250| saint-augustin
# Processing Record 251| ahipara
# Processing Record 252| mitsamiouli
# Processing Record 253| byron bay
# Processing Record 254| panacan
# Processing Record 255| mehamn
# City not found. Skipping...
# Processing Record 256| linxia
# Processing Record 257| ambovombe
# Processing Record 258| lata
# Processing Record 259| quatre cocos
# City not found. Skipping...
# Processing Record 260| bathsheba
# Processing Record 261| port elizabeth
# Processing Record 262| zeya
# Processing Record 263| kruisfontein
# Processing Record 264| berlevag
# Processing Record 265| kerchevskiy
# City not found. Skipping...
# Processing Record 266| mulchen
# Processing Record 267| parkes
# Processing Record 268| chumikan
# Processing Record 269| balabac
# Processing Record 270| vavoua
# Processing Record 271| bensonville
# Processing Record 272| hamilton
# Processing Record 273| grand gaube
# Processing Record 274| mareeba
# Processing Record 275| kentville
# Processing Record 276| erenhot
# Processing Record 277| kidal
# City not found. Skipping...
# Processing Record 278| port moresby
# Processing Record 279| bambous virieux
# Processing Record 280| tocopilla
# Processing Record 281| pointe michel
# Processing Record 282| batagay-alyta
# Processing Record 283| port hardy
# Processing Record 284| santa cruz de tenerife
# Processing Record 285| harwich
# City not found. Skipping...
# Processing Record 286| porto velho
# Processing Record 287| qom
# Processing Record 288| fort-shevchenko
# City not found. Skipping...
# Processing Record 289| yulara
# Processing Record 290| henties bay
# Processing Record 291| saldanha
# Processing Record 292| itoman
# Processing Record 293| paamiut
# Processing Record 294| acapulco
# Processing Record 295| bahia blanca
# Processing Record 296| pumiao
# Processing Record 297| kilindoni
# Processing Record 298| san cristobal
# Processing Record 299| aras
# Processing Record 300| soyo
# Processing Record 301| laguna
# Processing Record 302| lebu
# Processing Record 303| clyde river
# Processing Record 304| svetlogorsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 305| sharlyk
# City not found. Skipping...
# Processing Record 306| santo antonio do sudoeste
# City not found. Skipping...
# Processing Record 307| moranbah
# Processing Record 308| hobyo
# Processing Record 309| mumford
# Processing Record 310| leh
# Processing Record 311| camocim
# Processing Record 312| gazanjyk
# Processing Record 313| bandarbeyla
# Processing Record 314| buchanan
# Processing Record 315| dungarpur
# Processing Record 316| bonfim
# Processing Record 317| bahir dar
# Processing Record 318| pangody
# Processing Record 319| sidi ali
# Processing Record 320| inhambane
# Processing Record 321| kathu
# Processing Record 322| kozhevnikovo
# Processing Record 323| marsa matruh
# Processing Record 324| inhuma
# Processing Record 325| flinders
# Processing Record 326| swedru
# Processing Record 327| pierre
# Processing Record 328| huarmey
# Processing Record 329| nuuk
# Processing Record 330| eufaula
# Processing Record 331| neftcala
# Processing Record 332| fenoarivo
# Processing Record 333| kapiri mposhi
# Processing Record 334| omidiyeh
# Processing Record 335| de aar
# Processing Record 336| ostrovnoy
# Processing Record 337| douentza
# Processing Record 338| porbandar
# City not found. Skipping...
# Processing Record 339| katete
# Processing Record 340| kathmandu
# Processing Record 341| kamyshevatskaya
# Processing Record 342| daud khel
# Processing Record 343| birao
# Processing Record 344| mizdah
# City not found. Skipping...
# Processing Record 345| puerto escondido
# Processing Record 346| sheffield
# Processing Record 347| kuching
# Processing Record 348| hasaki
# City not found. Skipping...
# Processing Record 349| derzhavinsk
# Processing Record 350| thenzawl
# Processing Record 351| mulege
# Processing Record 352| fare
# City not found. Skipping...
# Processing Record 353| windhoek
# Processing Record 354| shangqiu
# Processing Record 355| cidreira
# Processing Record 356| plastun
# City not found. Skipping...
# Processing Record 357| pasni
# Processing Record 358| maceio
# Processing Record 359| trelew
# Processing Record 360| taungdwingyi
# City not found. Skipping...
# Processing Record 361| poopo
# Processing Record 362| kosa
# Processing Record 363| xushan
# Processing Record 364| tateyama
# Processing Record 365| los llanos de aridane
# Processing Record 366| haines junction
# Processing Record 367| touros
# Processing Record 368| platanos
# Processing Record 369| nevers
# Processing Record 370| egvekinot
# City not found. Skipping...
# Processing Record 371| sibolga
# City not found. Skipping...
# Processing Record 372| constantine
# City not found. Skipping...
# Processing Record 373| erdenet
# City not found. Skipping...
# Processing Record 374| loreto
# Processing Record 375| madanapalle
# Processing Record 376| lorengau
# City not found. Skipping...
# Processing Record 377| astorga
# Processing Record 378| lalmohan
# Processing Record 379| narsaq
# Processing Record 380| juneau
# Processing Record 381| fortuna
# Processing Record 382| la palma
# Processing Record 383| fort wellington
# Processing Record 384| bowen
# Processing Record 385| altagracia de orituco
# Processing Record 386| show low
# Processing Record 387| darab
# Processing Record 388| lennoxtown
# Processing Record 389| morros
# Processing Record 390| burnie
# Processing Record 391| kloulklubed
# Processing Record 392| trapani
# City not found. Skipping...
# Processing Record 393| iqaluit
# Processing Record 394| ratnagiri
# Processing Record 395| bahia honda
# Processing Record 396| safford
# Processing Record 397| camacupa
# Processing Record 398| port lincoln
# Processing Record 399| hovd
# Processing Record 400| camopi
# Processing Record 401| yartsevo
# Processing Record 402| zhuanghe
# Processing Record 403| tiznit
# City not found. Skipping...
# Processing Record 404| ponta delgada
# Processing Record 405| roebourne
# City not found. Skipping...
# Processing Record 406| weligama
# Processing Record 407| guerrero negro
# Processing Record 408| calatayud
# Processing Record 409| esmeralda
# Processing Record 410| mao
# Processing Record 411| zhengjiatun
# Processing Record 412| okhotsk
# Processing Record 413| bagotville
# City not found. Skipping...
# Processing Record 414| elban
# City not found. Skipping...
# Processing Record 415| garmisch-partenkirchen
# Processing Record 416| arlit
# Processing Record 417| nelson bay
# Processing Record 418| northam
# City not found. Skipping...
# Processing Record 419| tsiroanomandidy
# Processing Record 420| bayanday
# Processing Record 421| makokou
# Processing Record 422| gamba
# Processing Record 423| pimenta bueno
# Processing Record 424| samarai
# Processing Record 425| danville
# Processing Record 426| gao
# Processing Record 427| toul
# Processing Record 428| juegang
# Processing Record 429| yuli
# Processing Record 430| talara
# Processing Record 431| geraldton
# City not found. Skipping...
# Processing Record 432| leshukonskoye
# Processing Record 433| calabozo
# City not found. Skipping...
# Processing Record 434| imeni babushkina
# Processing Record 435| srednekolymsk
# Processing Record 436| tinskoy
# Processing Record 437| punta alta
# Processing Record 438| pilar
# Processing Record 439| sao joao da barra
# Processing Record 440| alamosa
# Processing Record 441| saskylakh
# Processing Record 442| arman
# Processing Record 443| te anau
# Processing Record 444| phuket
# Processing Record 445| mutoko
# City not found. Skipping...
# Processing Record 446| ouesso
# Processing Record 447| road town
# City not found. Skipping...
# Processing Record 448| fasa
# Processing Record 449| boende
# City not found. Skipping...
# Processing Record 450| kindu
# Processing Record 451| jinhua
# Processing Record 452| saurimo
# Processing Record 453| log
# City not found. Skipping...
# Processing Record 454| tilichiki
# Processing Record 455| vangaindrano
# Processing Record 456| khandbari
# Processing Record 457| stephenville
# Processing Record 458| lexington
# Processing Record 459| hualmay
# Processing Record 460| batemans bay
# Processing Record 461| namtsy
# Processing Record 462| eisenerz
# Processing Record 463| teguldet
# Processing Record 464| poltavka
# Processing Record 465| netarhat
# Processing Record 466| hoquiam
# Processing Record 467| puerto montt
# Processing Record 468| garmsar
# Processing Record 469| kasiri
# Processing Record 470| tuy hoa
# Processing Record 471| seymchan
# Processing Record 472| lakes entrance
# Processing Record 473| visina
# City not found. Skipping...
# Processing Record 474| fallingbostel
# Processing Record 475| mangrol
# Processing Record 476| jogindarnagar
# Processing Record 477| faya
# Processing Record 478| serenje
# Processing Record 479| beira
# Processing Record 480| nautanwa
# Processing Record 481| nome
# Processing Record 482| zhigansk
# Processing Record 483| udachnyy
# City not found. Skipping...
# Processing Record 484| campbell river
# Processing Record 485| grindavik
# Processing Record 486| russell
# Processing Record 487| samana
# Processing Record 488| oda
# Processing Record 489| agadez
# Processing Record 490| at-bashi
# Processing Record 491| mikuni
# Processing Record 492| ahuimanu
# Processing Record 493| sarakhs
# Processing Record 494| iracoubo
# Processing Record 495| novoagansk
# Processing Record 496| aktau
# City not found. Skipping...
# Processing Record 497| alice springs
# Processing Record 498| marsh harbour
# Processing Record 499| harper
# Processing Record 500| ust-kuyga
# Processing Record 501| norsup
# Processing Record 502| aklavik
# Processing Record 503| camacha
# Processing Record 504| malpe
# Processing Record 505| redlands
# Processing Record 506| tim
# Processing Record 507| wanning
# Processing Record 508| takoradi
# Processing Record 509| abu samrah
# Processing Record 510| moron
# Processing Record 511| santa cruz
# Processing Record 512| yarmouth
# Processing Record 513| buala
# Processing Record 514| chimbote
# Processing Record 515| santiago
# Processing Record 516| aripuana
# City not found. Skipping...
# Processing Record 517| eskil
# Processing Record 518| araouane
# Processing Record 519| porto seguro
# Processing Record 520| bay saint louis
# City not found. Skipping...
# Processing Record 521| suez
# Processing Record 522| omboue
# Processing Record 523| astana
# Processing Record 524| cacoal
# Processing Record 525| ekhabi
# City not found. Skipping...
# Processing Record 526| buin
# Processing Record 527| santa rosalia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 528| morris
# Processing Record 529| mildura
# Processing Record 530| kalmunai
# Processing Record 531| naze
# Processing Record 532| tinaquillo
# Processing Record 533| nemuro
# City not found. Skipping...
# Processing Record 534| skegness
# Processing Record 535| isangel
# Processing Record 536| qasigiannguit
# Processing Record 537| misrikh
# Processing Record 538| veraval
# Processing Record 539| salinopolis
# Processing Record 540| granville
# Processing Record 541| annapolis
# Processing Record 542| sembakung
# City not found. Skipping...
# Processing Record 543| canutama
# City not found. Skipping...
# Processing Record 544| diu
# Processing Record 545| kibre mengist
# Processing Record 546| aranos
# Processing Record 547| sebring
# Processing Record 548| mporokoso
# Processing Record 549| gladstone
# Processing Record 550| mazatlan
# Processing Record 551| chicama
# Processing Record 552| devarkonda
# City not found. Skipping...
# Processing Record 553| labuhan
# Processing Record 554| bar harbor
# Processing Record 555| halmasd
# Processing Record 556| panormos

# %%
all_cities[0]
# Out:
# {'coord': {'lon': -117.57, 'lat': 53.4},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'model',
#  'main': {'temp': 260.58,
#   'feels_like': 256.02,
#   'temp_min': 260.58,
#   'temp_max': 260.58,
#   'pressure': 1006,
#   'humidity': 97,
#   'sea_level': 1006,
#   'grnd_level': 858},
#  'wind': {'speed': 1.87, 'deg': 78},
#  'snow': {'3h': 0.94},
#  'clouds': {'all': 100},
#  'dt': 1578450793,
#  'sys': {'country': 'CA', 'sunrise': 1578413032, 'sunset': 1578440914},
#  'timezone': -25200,
#  'id': 5975503,
#  'name': 'Hinton',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame([{
    "City": d["name"],
    "Country": d["sys"].get('country', ''),
    "Date": d["dt"],
    "Latitude": d["coord"].get('lat', ''),
    "Longitude": d["coord"].get('lon', ''),
    "Temp": d["main"]["temp"] - 273.15,
    "Temp Min": d["main"]["temp_min"],
    "Temp Max": d["main"]["temp_max"],
    "Pressure": d["main"]["pressure"],
    "Humidity": d["main"]["humidity"],
    "Clouds": d["clouds"].get("all", ""),
    "Wind Speed": d["wind"].get("speed", "")
} for d in all_cities])

# %%
df['Max F'] = (df["Temp Max"] - 273.15) * (9/5) + 32
df['Wind Speed'] = df["Wind Speed"] * 2.237

# %%
df.to_csv('all_cities.csv')

# %%
df.head()
# Out:
#            City Country        Date  Latitude  Longitude   Temp  Temp Min  \
# 0        Hinton      CA  1578450793     53.40    -117.57 -12.57    260.58
# 1         Ilebo      CD  1578450793     -4.33      20.59  20.36    293.51
# 2  Punta Arenas      CL  1578450793    -53.16     -70.91  10.00    283.15
# 3         Pevek      RU  1578450793     69.70     170.27 -24.34    248.81
# 4      Adelaide      AU  1578450793    -34.93     138.60  33.24    303.15
#
#    Temp Max  Pressure  Humidity  Clouds  Wind Speed   Max F
# 0    260.58      1006        97     100     4.18319   9.374
# 1    293.51      1010        98     100     1.76723  68.648
# 2    283.15       980        76      75    19.46190  50.000
# 3    248.81      1015        81       0    13.77992 -11.812
# 4    308.71      1013         9       0     4.00423  96.008

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df["Latitude"], df["Max F"], c = "teal", alpha = 0.5, marker = 'o')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f'City Latitude Vs. Max Temperature ({time.strftime("%m/%d/%Y")})')
plt.grid()
plt.savefig("latitude_vs_maxtemp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df["Latitude"], df["Humidity"], c = 'teal', alpha = 0.5, marker = 'o')
plt.title(f'City Latitude Vs. Humidity ({time.strftime("%m/%d/%Y")})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("latitude_vs_humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Latitude"], df["Clouds"], c = 'teal', alpha = 0.5, marker = 'o')
plt.title(f'City Latitude Vs. Cloudiness ({time.strftime("%m/%d/%Y")})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("latitude_vs_cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Latitude"], df["Wind Speed"], c = 'teal', alpha = 0.5, marker = 'o')
plt.title(f'City Latitude Vs. Wind Speed ({time.strftime("%m/%d/%Y")})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.grid()
plt.savefig("latitude_vs_windspeed.png")

plt.show()
